# %%
class a :
    def do_this(self):
        print("Doing this in class a")
        
class b(a):
    pass 
class c(b):
    def do_this(self):
        print("Doing something in class c")
class d(c,b):
    pass
class e(a):
    def do_this(self):
        print("Doing something in class e")

# %%
obj = a()
obj.do_this()
# Out:
# Doing this in class a
