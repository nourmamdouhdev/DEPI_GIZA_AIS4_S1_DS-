# %%
print("hello")
# Out:
# hello

# %%
print("world")
# Out:
# world

# %%
x= 30 
print (x)
# Out:
# 30

# %%
id(x)
x=10

# %%
name = "goerg"
age = 35 
"my name is {} and my age is {}".format(name,age)
# Out:
# 'my name is goerg and my age is 35'
