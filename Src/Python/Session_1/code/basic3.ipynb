# %%
list_one = [1, 2, 3, 4, "depi","learing",True,[1,2,3,True,["ml","ai",123]]]
print (type(list_one))
# Out:
# <class 'list'>

# %%
list_one [7][4][0] = "ArithmeticError"
list_one [7][4][0]
# Out:
# 'ArithmeticError'

# %%
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'learing',
#  True,
#  [1, 2, 3, True, ['ArithmeticError', 'ai', 123]]]

# %%
name = "Depi"
list(name)
# Out:
# ['D', 'e', 'p', 'i']

# %%
list_1 = [1, 2, 3]
list_2 = [4, 5, 6]
list_3 = list_1 + list_2
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1 = [1, 2, 3]
list_1.remove(2)
list_1
# Out:
# [1, 3]

# %%
input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]
itmem = input("enter ur itme")
input_list.remove(itmem)

# %%
list_1 = [1, 2, 3]
list_1.index(2)
# Out:
# 1

# %%
a= 300
b=33
if b > a:
  print("b is greater than a")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
list_1 = [1, 2, 3]
list_2 = [4, 5, 6]
list_1.index(2)
if 2 in list_1:
    print("yes, 2 is in the list")
# Out:
# yes, 2 is in the list

# %%
x=20 
result= "even" if x % 2 == 0 else "odd"
print(result)
